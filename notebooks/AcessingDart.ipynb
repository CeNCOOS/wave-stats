# %%
import xarray as xr

# %%
url = "https://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/realtime/157p1_xy.nc"
# url = "https://www.ngdc.noaa.gov/thredds/dodsC/dart_bpr/processed/32411/32411_20160318to20180206_qc.nc"
ds = xr.open_dataset(url)

# %%
# ds
# ds['seafloor_pressure_abs_quality_controlled'].isel(time=slice(-10100,-10000)).plot(marker='x')

# %%
ds["xyzZDisplacement"].isel(xyzCount=slice(-200,-1)).plot()

# %%
ds['xyzSampleRate']
# Out:
# <xarray.DataArray 'xyzSampleRate' ()>
# array(1.28)
# Coordinates:
#     metaDeployLatitude   float32 43.77012
#     metaDeployLongitude  float32 -124.548836
# Attributes:
#     long_name:  displacement output sample rate
#     units:      hertz
